# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from sklearn.impute import SimpleImputer, KNNImputer
import networkx as nx
import seaborn as sns
import json
import glob
import os

# %%
# Create the graph from the JSON files

with open('../json/nodes.json', 'r') as f:
    nodes = json.load(f)

with open('../json/links.json', 'r') as f:
    links = json.load(f)

G = nx.DiGraph()

for node in nodes:
    G.add_node(node['id'], **node)

for link in links:
    G.add_edge(link['us_node_id'], link['ds_node_id'], **link)

pos = {node["id"]: (node["x"], node["y"]) for node in nodes}

# %%
# Load the data

# Directory containing all the CSV files
folder_path = '../Run_C2100_Gebeurtenis_DWA_20250422_003112'

# Prefix of the files to be loaded
prefix = 'Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_'

# multiple pickle path
multiple_pickle_path = '../pickle/multiple/depnod_volume_05.pkl'

# List to collect matching files
matching_files = []

# Walk through the folder
for file_name in os.listdir(folder_path):
    if file_name.startswith(prefix):
        matching_files.append(file_name)

# Print or use the list
for f in matching_files:
    print(f)
# Out:
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_depnod.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_flooddepth.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_floodvolume.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_flvol.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_qinfnod.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_qnode.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_qrain.csv
# Node_Run_C2100_Gebeurtenis_DWA_20250422_003112_BRC_PDCs_6_33;1_61; bui#10_volume.csv

# %%
# 1. Load the data of first matching file (depnod)
depnod_df = pd.read_csv(os.path.join(folder_path, matching_files[0]), skiprows=[1])
depnod_df.drop(columns=['Time'], inplace=True)
depnod_df.replace(-9998.0, np.nan, inplace=True)

# 2. Select depth columns and identify negative values
depth_columns = depnod_df.columns.difference(['Seconds'])
negatives = depnod_df[depth_columns] < 0

# 3. Count total negative values and nodes with negatives
total_negatives = negatives.sum().sum()
nodes_with_negatives = negatives.any()
count_nodes_with_negatives = nodes_with_negatives.sum()
nodes_list = nodes_with_negatives[nodes_with_negatives].index.tolist()

print(f"Total number of negative depth entries: {total_negatives}")
print(f"Number of nodes with at least one negative depth: {count_nodes_with_negatives}")
print(f"Nodes with negatives: {nodes_list}")

# 4. Columns where ALL values are negative
columns_all_negative = (depnod_df[depth_columns] < 0).all()
columns_all_negative = columns_all_negative[columns_all_negative].index.tolist()
depnod_df[columns_all_negative] = np.nan

# 5. Columns where ALL values are NaN
nan_columns_names = depnod_df.columns[depnod_df.isna().all()].tolist()
Percentage = len(nan_columns_names) / len(depnod_df.columns) * 100
'333052C2', '333052R', '333052U1', '333052U2', '333052U3', '333053', '333054', '333054R', '333055R', '333056', '333057', '333058', '333059', '333063R', '333064A', '333064R', '333065D', '333066D', '333067D', '333068D', '333069D', '333070D', '333079', '333080', '333081', '333082', '333083', '333083g', '333094', '333096', '333097', '333098', '333099', '333117', '333122', '333123', '333124', '334013C2', '334027', '334027A', '334028', '334029', '334030', '334031', '334032', '334042C2', '334043', '334075', '334076', '334077', '334078', '334079', '334080', '334081', '334082', '334085', '334 ...
# Percentage of columns where ALL values are NaN: 3.79%
# Number of columns where ALL values are NaN: 244
# This could be imputed with KNN or SimpleImputer

# %%
print(f'There are {len(nan_columns_names)} columns where all values are NaN')
# Let's add the data to the graph
for node in depnod_df.columns[1:]:
    if node in G.nodes:
        G.nodes[node]['depth'] = depnod_df[node].tolist()
    else:
        print(f"Node {node} not found in the graph.")

print((G.nodes(data=True)))
# Out:
# There are 244 columns where all values are NaN
# [('1001', {'id': '1001', 'x': 461000.65616613504, 'y': 1351690.2559001052, 'depth': [1.12051, 1.18279, 1.74043, 2.90192, 2.97986, 3.03615, 3.07451, 3.09978, 3.11576, 3.12408, 3.12541, 3.1221, 3.11706]}), ('1002', {'id': '1002', 'x': 460883.5301818835, 'y': 1351714.5341153282, 'depth': [1.04101, 1.09897, 1.75588, 2.89637, 2.96546, 3.01849, 3.05703, 3.08344, 3.10009, 3.10857, 3.1098, 3.10637, 3.10133]}), ('1003', {'id': '1003', 'x': 460754.625982409, 'y': 1351744.3241415746, 'depth': [0.91088, 0.95011, 1.66943, 2.88485, 2.94737, 2.98897, 3.02149, 3.04463, 3.05973, 3.06772, 3.0692, 3.0664, 3.06206]}), ('1004', {'id': '1004', 'x': 460639.6981608872, 'y': 1351745.505243937, 'depth': [0.84101, 0.87855, 1.59096, 2.83723, 2.90732, 2.94641, 2.97352, 2.99373, 3.00766, 3.01552, 3.01765, 3.01583, 3.0123]}), ('1005', {'id': '1005', 'x': 460507.77558870916, 'y': 1351746.6207295011, 'depth': [0.75108, 0.8539, 1.51705, 2.69795, 2.81182, 2.86532, 2.89756, 2.91937, 2.934, 2.94265, 2.94563, 2.94439, 2.94037]}), ('1006', {'id': '1006', 'x': 460477.6574784731, 'y': 1351743.2742728083, 'depth': [1.15067, 1.29807, 1.88773, 2.94709, 3.02389, 3.07151, 3.10318, 3.12315, 3.13405, 3.13714, 3.13282, 3.12372, 3.11271]}), ('1007', {'id': '1007', 'x': 460543.5695519636, 'y': 1351620.078734751, 'depth': [0.66141, 0.79828, 1.42808, 2.56866, 2.70525, 2.76834, 2.80922, 2.83707, 2.8559, 2.86754, 2.87282, 2.87305, 2.86926]}), ('1008', {'id': '1008', 'x': 460588.1233577377, 'y': 1351465.223091707, 'depth': [0.58676, 0.75922, 1.21562, 2.49067, 2.68187, 2.74488, 2.78211, 2.8032, 2.81194, 2.80907, 2.79276, 2.7597, 2.7034]}), ('1009', {'id': '1009', 'x': 460630.7414679738, 'y': 1351316.1089184794, 'depth': [0.56118, 0.72232, 1.06463, 2.42859, 2.6696, 2.72574, 2.75619, 2.76894, 2.76643, 2.74699, 2.70079, 2.6109, 2.50432]}), ('1010', {'id': '1010', 'x': 460671.3254574749, 'y': 1351173.8517006321, 'depth': [0.52226, 0.67789, 0.99701, 2.36359, 2.65563, 2.70533, 2.72897, 2.73331, 2.7197, 2.6852, 2.61132, 2.51688, 2.43151]}), ('1011', {'id': '1011', 'x': 460715.55117925955, 'y': 1351018.9632491893, 'depth': [0.50697, 0.61612, 0.88748, 2.23151, 2.61622, 2.65327, 2.6624, 2.64845, 2.61571, 2.56564, 2.48239, 2.4109, 2.35116]}), ('1012', {'id': '1012', 'x': 460758.92388267146, 'y': 1350870.1443515518, 'depth': [0.44627, 0.51204, 0.75793, 2.16379, 2.56597, 2.59528, 2.59924, 2.58198, 2.54846, 2.50047, 2.42286, 2.36459, 2.31659]}), ('1013', {'id': '1013', 'x': 460798.98293778935, 'y': 1350728.9370024712, 'depth': [-0.08598, -0.03471, 0.2796, 2.08652, 2.48712, 2.50717, 2.50764, 2.49239, 2.46586, 2.42752, 2.36263, 2.31946, 2.28342]}), ('1014R', {'id': '1014R', 'x': 460793.5761136424, 'y': 1350654.1896271433, 'depth': [0.9535, 0.96926, 1.01857, 1.11234, 1.1857, 1.21625, 1.22157, 1.21101, 1.189, 1.15845, 1.11999, 1.08098, 1.04953]}), ('1014U', {'id': '1014U', 'x': 460822.69684855046, 'y': 1350662.5360838363, 'depth': [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]}), ('101568C2', {'id': '101568C2', 'x': 452129.31758349336, 'y': 1348141.2631179672, 'depth': [1.14351, 1.1834, 1.73161, 2.24014, 3.41832, 3.53752, 3.54258, 3.48378, 3.37053, 3.18663, 2.92213, 2.65428, 2.4947]}), ('1019R', {'id': '1019R', 'x': 460833.366139889, 'y': 1350520.9842465664, 'depth': [0.9935, 1.01053, 1.07244, 1.18581, 1.2811, 1.3237, 1.33164, 1.31663, 1.28589, 1.24462, 1.19424, 1.14428, 1.10466]}), ('1020', {'id': '1020', 'x': 460892.88057558425, 'y': 1350328.3464512918, 'depth': [1.40151, 1.52873, 1.86813, 2.70013, 2.92753, 2.98258, 3.01834, 3.03887, 3.04723, 3.04456, 3.02996, 3.00687, 2.98051]}), ('1020R', {'id': '1020R', 'x': 460882.91338398325, 'y': 1350348.6843778007, 'depth': [1.0435, 1.07372, 1.14818, 1.2526, 1.35005, 1.39777, 1.40706, 1.38896, 1.35289, 1.306, 1.25027, 1.19687, 1.15646]}), ('1021', {'id': '1021', 'x': 460937.36876456044, 'y': 1350171.9160050983, 'depth': [1.51135, 1.64371, 2.05495, 3.01055, 3.10979, 3.16224, 3.19749, 3.22136, 3.2367, 3.2449, 3.24649, 3.24337, 3.2376]}), ('1 ...

# %%
from collections import deque

# Function to find closest valid neighbors using BFS
count = 0
countn = 0
def find_closest_valid_neighbors(graph, start_node):
    valid_neighbors = []
    visited = set()
    queue = [(start_node, 0)]  # BFS starts from the start node with distance 0
    
    # Perform BFS
    while queue:
        current, distance = queue.pop(0)
        if current in visited:
            continue
        visited.add(current)
        
        # Skip the start node itself
        if current != start_node:
            depths = graph.nodes[current]['depth']
            # Check if any depth is valid (not NaN)
            if any(not np.isnan(d) for d in depths):
                valid_neighbors.append(current)
        
        # Enqueue neighbors with distance incremented by 1
        for neighbor in graph.neighbors(current):
            if neighbor not in visited:
                queue.append((neighbor, distance + 1))
    
    return valid_neighbors

valid_neighbors_list = []
invalid_neighbors_list = []
# Fill missing data
for node in G.nodes:
    depths = G.nodes[node]['depth']
    if all(np.isnan(d) for d in depths):
        count += 1
        print(f"\nFilling node {node}")
        
        # Find neighbors
        valid_neighbors = find_closest_valid_neighbors(G, node)
        print(f"  Found valid neighbors: {valid_neighbors}")
        
        if valid_neighbors:
            countn += 1
            valid_neighbors_list.append(node)
            # Get the depth data for valid neighbors
            neighbor_depths = [G.nodes[n]['depth'] for n in valid_neighbors]
            aggregated = []
            for time_step in zip(*neighbor_depths):
                valid_values = [v for v in time_step if not np.isnan(v)]
                if valid_values:
                    aggregated.append(np.mean(valid_values))
                else:
                    aggregated.append(np.nan)
            # Update the node's depth
            G.nodes[node]['depth'] = aggregated
        else:
            print(f"  No valid data found for node {node} (remains NaN)")
            invalid_neighbors_list.append(node)

# Print results
print("\nUpdated node depths:")
for node in G.nodes:
    print(f"{node}: {G.nodes[node]['depth']}")

print(f'Total number of nodes with all NaN values: {count}')
print(f'Total number of nodes with at least one valid neighbor: {countn}')
print(f'Valid neighbors: {valid_neighbors_list}')
print(f'Invalid neighbors: {invalid_neighbors_list}')
print(f"Percentage of nodes which were filled: {countn / count * 100:.2f}%")
print(f"Percentage of nodes which were not filled: {100 - (countn / count * 100):.2f}%")
# Out:
# Filling node 1014U
#   Found valid neighbors: []
#   No valid data found for node 1014U (remains NaN)
#
# Filling node 1030U
#   Found valid neighbors: []
#   No valid data found for node 1030U (remains NaN)
#
# Filling node 110076U1
#   Found valid neighbors: []
#   No valid data found for node 110076U1 (remains NaN)
#
# Filling node 110076U2
#   Found valid neighbors: ['110061C2']
#
# Filling node 110126KRAT_out
#   Found valid neighbors: []
#   No valid data found for node 110126KRAT_out (remains NaN)
#
# Filling node 110413I_out
#   Found valid neighbors: []
#   No valid data found for node 110413I_out (remains NaN)
#
# Filling node 110414I_out
#   Found valid neighbors: []
#   No valid data found for node 110414I_out (remains NaN)
#
# Filling node 110426_out
#   Found valid neighbors: []
#   No valid data found for node 110426_out (remains NaN)
#
# Filling node 110516H_OUT
#   Found valid neighbors: []
#   No valid data found for node 110516H_OUT (remains NaN)
#
# Filling node 110527I_out
#   Found valid neighbors: []
#   No valid data found for node 110527I_out (remains NaN)
#
# Filling node 110528I_out
#   Found valid neighbors: []
#   No valid data found for node 110528I_out (remains NaN)
#
# Filling node 1116U
#   Found valid neighbors: []
#   No valid data found for node 1116U (remains NaN)
#
# Filling node 121589-1U2
#   Found valid neighbors: []
#   No valid data found for node 121589-1U2 (remains NaN)
#
# Filling node 130527A_out
#   Found valid neighbors: []
#   No valid data found for node 130527A_out (remains NaN)
#
# Filling node 140784_INF_OUT
#   Found valid neighbors: []
#   No valid data found for node 140784_INF_OUT (remains NaN)
#
# Filling node 141236U
#   Found valid neighbors: []
#   No valid data found for node 141236U (remains NaN)
#
# Filling node 143254
#   Found valid neighbors: ['143267C3']
#
# Filling node 143255
#   Found valid neighbors: ['143267C2']
#
# Filling node 143307U
#   Found valid neighbors: ['143307C2']
#
# Filling node 150055U
#   Found valid neighbors: []
#   No valid data found for node 150055U (remains NaN)
#
# Filling node 150161U
#   Found valid neighbors: []
#   No valid data found for node 150161U (remains NaN)
#
# Filling node 150202PU
#   Found valid neighbors: []
#   No valid data found for node 150202PU (remains NaN)
#
# Filling node 150329VRW_U
#   Found valid neighbors: []
#   No valid data found for node 150329VRW_U (remains NaN)
#
# Filling node 160004
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160009U
#   Found valid neighbors: []
#   No valid data found for node 160009U (remains NaN)
#
# Filling node 160024
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160025
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160027
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160029
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160031
#   Found valid neighbors: ['150104', '150109', '150110', '150111', '150112', '150113', '150114', '150115', '150116', '150117', '150118', '150119', '150166', '150167', '4067RGWS']
#
# Filling node 160034
#   Found valid neighbors: []
#   No valid data found for node 160034 (remains NaN)
#
# Filling node 170000
#   Found valid neighbors: ['PRS185', '121515', '121516', '121522', '121536', '121544', '121537', '121538', '121539']
#
# Filling node 170011
#   Found valid neighbors: ['170107']
#
# Filling node 170013
#   Found valid neighbors: []
#   No valid data found for node 170013 (remains NaN)
#
# Filling node 170015
#   Found valid neighbors: []
#   No valid data found for node 170015 (remains NaN)
#
# Filling node 170017
#   Found valid neighbors: []
#   No valid data found for node 170017 (remains NaN)
#
# Filling node 170020U
#   Found valid neighbors: []
#   No valid data found for node 170020U (remains NaN)
#
# Filling node 170021
#   Found valid neighbors: []
#   No valid data found for node 170021 (remains NaN)
#
# Filling node 170023
#   Found valid neighbors: []
#   No valid data found for node 170023 (remains NaN)
#
# Filling node 170025
#   Found valid neighbors: ['170084', '170085', '170086', '170087']
#
# Filling node 170025E
#   Found valid neighbors: []
#   No valid data found for node 170025E (remains NaN)
#
# Filling node 170026
#   Found valid neighbors: []
#   No valid data found for node 170026 (remains NaN)
#
# Filling node 170027
#   Found valid neighbors: []
#   No valid data found for node 170027 (remains NaN)
#
# Filling node 170030
#   Found valid neighbors: []
#   No valid data found for node 170030 (remains NaN)
#
# Filling node 170032
#   Found valid neighbors: ['170082', '170035', '170102', '170036', '170037', '170059', '170039', '170040', '170093', '170053', '170055', '170056']
#
# Filling node 170063
#   Found valid neighbors: []
#   No valid data found for node 170063 (remains NaN)
#
# Filling node 170071
#   Found valid neighbors: []
#   No valid data found for node 170071 (remains NaN)
#
# Filling node 170100U
#   Found valid neighbors: []
#   No valid data found for node 170100U (remains NaN)
#
# Filling node 170106
#   Found valid neighbors: []
#   No valid data found for node 170106 (remains NaN)
#
# Filling node 170116C2
#   Found valid neighbors: []
#   No valid data found for node 170116C2 (remains NaN)
#
# Filling node 170116U
#   Found valid neighbors: []
#   No valid data found for node 170116U (remains NaN)
#
# Filling node 170117
#   Found valid neighbors: []
#   No valid data found for node 170117 (remains NaN)
#
# Filling node 170119U
#   Found valid neighbors: []
#   No valid data found for node 170119U (remains NaN)
#
# Filling node 170125U
#   Found valid neighbors: []
#   No valid data found for node 170125U (remains NaN)
#
# Filling node 170139U
#   Found valid neighbors: []
#   No valid data found for node 170139U (remains NaN)
#
# Filling node 170139UPUT_out
#   Found valid neighbors: []
#   No valid data found for node 170139UPUT_out (remains NaN)
#
# Filling node 170143U
#   Found valid neighbors: []
#   No valid data found for node 170143U (remains NaN)
#
# Filling node 170155U2
#   Found valid neighbors: ['170155R', '170155RC2']
#
# Filling node 170170U
#   Found valid neighbors: []
#   No valid data found for node 170170U (remains NaN)
#
# Filling node 170190ROV_out
#   Found valid neighbors: []
#   No valid data found for node 170190ROV_out (remains NaN)
#
# Filling node 171007U
#   Found valid neighbors: []
#   No valid data found for node 171007U (remains NaN)
#
# Filling node 180022I_out
#   Found valid neighbors: []
#   No valid data found for node 180022I_out (remains NaN)
#
# Filling node 180030U
#   Found valid neighbors: []
#   No valid data found for node 180030U (remains NaN)
#
# Filling node 190026U
#   Found valid neighbors: []
#   No valid data found for node 190026U (remains NaN)
#
# Filling node 2131AQUA_out
#   Found valid neighbors: []
#   No valid data found for node 2131AQUA_out (remains NaN)
#
# Filling node 2257AQUA_out
#   Found valid neighbors: []
#   No valid data found for node 2257AQUA_out (remains NaN)
#
# Filling node 2576U
#   Found valid neighbors: []
#   No valid data found for node 2576U (remains NaN)
#
# Filling node 2672U
#   Found valid neighbors: []
#   No valid data found for node 2672U (remains NaN)
#
# Filling node 2718U
#   Found valid neighbors: []
#   No valid data found for node 2718U (remains NaN)
#
# Filling node 3023AQUA_out
#   Found valid neighbors: []
#   No valid data found for node 3023AQUA_out (remains NaN)
#
# Filling node 3035_AQUA_OUT
#   Found valid neighbors: []
#   No valid data found for node 3035_AQUA_OUT (remains NaN)
#
# Filling node 3150S_OUT
#   Found valid neighbors: []
#   No valid data found for node 3150S_OUT (remains NaN)
#
# Filling node 3258_out
#   Found valid neighbors: []
#   No valid data found for node 3258_out (remains NaN)
#
# Filling node 3268S_OUT
#   Found valid neighbors: []
#   No valid data found for node 3268S_OUT (remains NaN)
#
# Filling node 332009U
#   Found valid neighbors: []
#   No valid data found for node 332009U (remains NaN)
#
# Filling node 332040U
#   Found valid neighbors: []
#   No valid data found for node 332040U (remains NaN)
#
# Filling node 332053
#   Found valid neighbors: []
#   No valid data found for node 332053 (remains NaN)
#
# Filling node 332054
#   Found valid neighbors: []
#   No valid data found for node 332054 (remains NaN)
#
# Filling node 333050U_OUT
#   Found valid neighbors: []
#   No valid data found for node 333050U_OUT (remains NaN)
#
# Filling node 333052U1
#   Found valid neighbors: []
#   No valid data found for node 333052U1 (remains NaN)
#
# Filling node 333052U2
#   Found valid neighbors: []
#   No valid data found for node 333052U2 (remains NaN)
#
# Filling node 333052U3
#   Found valid neighbors: []
#   No valid data found for node 333052U3 (remains NaN)
#
# Filling node 333054U1
#   Found valid neighbors: []
#   No valid data found for node 333054U1 (remains NaN)
#
# Filling node 333054U2
#   Found valid neighbors: []
#   No valid data found for node 333054U2 (remains NaN)
#
# Filling node 333055R
#   Found valid neighbors: []
#   No valid data found for node 333055R (remains NaN)
#
# Filling node 334013C2
#   Found valid neighbors: []
#   No valid data found for node 334013C2 (remains NaN)
#
# Filling node 334013U
#   Found valid neighbors: []
#   No valid data found for node 334013U (remains NaN)
#
# Filling node 334026
#   Found valid neighbors: []
#   No valid data found for node 334026 (remains NaN)
#
# Filling node 334042C2
#   Found valid neighbors: []
#   No valid data found for node 334042C2 (remains NaN)
#
# Filling node 334042U
#   Found valid neighbors: []
#   No valid data found for node 334042U (remains NaN)
#
# Filling node 334045U
#   Found valid neighbors: []
#   No valid data found for node 334045U (remains NaN)
#
# Filling node 334089IK_out
#   Found valid neighbors: []
#   No valid data found for node 334089IK_out (remains NaN)
#
# Filling node 334089U
#   Found valid neighbors: []
#   No valid data found for node 334089U (remains NaN)
#
# Filling node 334126U
#   Found valid neighbors: ['334126C2']
#
# Filling node 334142R
#   Found valid neighbors: []
#   No valid data found for node 334142R (remains NaN)
#
# Filling node 334148
#   Found valid neighbors: ['334143']
#
# Filling node 334149
#   Found valid neighbors: []
#   No valid data found for node 334149 (remains NaN)
#
# Filling node 334150
#   Found valid neighbors: []
#   No valid data found for node 334150 (remains NaN)
#
# Filling node 335031U
#   Found valid neighbors: []
#   No valid data found for node 335031U (remains NaN)
#
# Filling node 335031U2
#   Found valid neighbors: []
#   No valid data found for node 335031U2 (remains NaN)
#
# Filling node 336001U
#   Found valid neighbors: []
#   No valid data found for node 336001U (remains NaN)
#
# Filling node 336105U
#   Found valid neighbors: []
#   No valid data found for node 336105U (remains NaN)
#
# Filling node 336315
#   Found valid neighbors: ['336329C2']
#
# Filling node 336378U
#   Found valid neighbors: []
#   No valid data found for node 336378U (remains NaN)
#
# Filling node 336440U
#   Found valid neighbors: []
#   No valid data found for node 336440U (remains NaN)
#
# Filling node 3511INF.1
#   Found valid neighbors: []
#   No valid data found for node 3511INF.1 (remains NaN)
#
# Filling node 3511INFIL._out
#   Found valid neighbors: []
#   No valid data found for node 3511INFIL._out (remains NaN)
#
# Filling node 3834AU
#   Found valid neighbors: []
#   No valid data found for node 3834AU (remains NaN)
#
# Filling node 3850U
#   Found valid neighbors: []
#   No valid data found for node 3850U (remains NaN)
#
# Filling node 3948U
#   Found valid neighbors: []
#   No valid data found for node 3948U (remains NaN)
#
# Filling node 3978IK_out
#   Found valid neighbors: []
#   No valid data found for node 3978IK_out (remains NaN)
#
# Filling node 4013AQUA_out
#   Found valid neighbors: []
#   No valid data found for node 4013AQUA_out (remains NaN)
#
# Filling node 4054IK_out
#   Found valid neighbors: []
#   No valid data found for node 4054IK_out (remains NaN)
#
# Filling node 4067RGWSU
#   Found valid neighbors: []
#   No valid data found for node 4067RGWSU (remains NaN)
#
# Filling node 4074U
#   Found valid neighbors: []
#   No valid data found for node 4074U (remains NaN)
#
# Filling node 4120OU
#   Found valid neighbors: []
#   No valid data found for node 4120OU (remains NaN)
#
# Filling node 4131
#   Found valid neighbors: ['4132', '4133']
#
# Filling node 4134
#   Found valid neighbors: ['4135']
#
# Filling node 4143
#   Found valid neighbors: ['4144', '4143LP', '4072A', '4072', '4070', '4073', '4121']
#
# Filling node 4143P
#   Found valid neighbors: ['4143LP', '4072A', '4072', '4070', '4073', '4121']
#
# Filling node 4170 U
#   Found valid neighbors: []
#   No valid data found for node 4170 U (remains NaN)
#
# Filling node 4181 U
#   Found valid neighbors: []
#   No valid data found for node 4181 U (remains NaN)
#
# Filling node 4222F_out
#   Found valid neighbors: []
#   No valid data found for node 4222F_out (remains NaN)
#
# Filling node 4235I_out
#   Found valid neighbors: []
#   No valid data found for node 4235I_out (remains NaN)
#
# Filling node 4236I_out
#   Found valid neighbors: []
#   No valid data found for node 4236I_out (remains NaN)
#
# Filling node 4237I_out
#   Found valid neighbors: []
#   No valid data found for node 4237I_out (remains NaN)
#
# Filling node 4238I_out
#   Found valid neighbors: []
#   No valid data found for node 4238I_out (remains NaN)
#
# Filling node 4239I_out
#   Found valid neighbors: []
#   No valid data found for node 4239I_out (remains NaN)
#
# Filling node 4310U1
#   Found valid neighbors: ['R4310', '4310U2']
#
# Filling node 4310U3
#   Found valid neighbors: []
#   No valid data found for node 4310U3 (remains NaN)
#
# Filling node 4310U4
#   Found valid neighbors: []
#   No valid data found for node 4310U4 (remains NaN)
#
# Filling node 4317V
#   Found valid neighbors: ['4302V', '4321V', '4301V', '4375V', '4328V', '4305V', '4397V', '4319V', '3586', '4304V', '4396V', '4322V', '3663', '4308V', '4303V', '4398V', '4376V', '3946', '4307V', '4310V', '4386V', '4393V', '4330V', '3946C2', '4306V', '4311V', '4394V', '4323V', '4313V', '4314V', '4395V', '4323BLIND1', '4378V', '4312V', '4316V', '4315V', '4401V', '4379V', '4309V', '4399V']
#
# Filling node 4320RG
#   Found valid neighbors: ['4328V', '3586', '3663', '3946', '3946C2']
#
# Filling node 4320V
#   Found valid neighbors: ['4321V', '4320RG', '4375V', '4328V', '4397V', '4319V', '3586', '4396V', '4322V', '3663', '4398V', '4376V', '3946', '4386V', '4393V', '4330V', '3946C2', '4394V', '4323V', '4395V', '4323BLIND1', '4378V', '4401V', '4379V', '4399V']
#
# Filling node 4336U1
#   Found valid neighbors: []
#   No valid data found for node 4336U1 (remains NaN)
#
# Filling node 4346U2
#   Found valid neighbors: []
#   No valid data found for node 4346U2 (remains NaN)
#
# Filling node 4349U-1
#   Found valid neighbors: ['4350K', 'Berging_Hongerenburgweg']
#
# Filling node 4376u
#   Found valid neighbors: ['4376R', '4375R']
#
# Filling node 4379U
#   Found valid neighbors: ['4379R', '4378R']
#
# Filling node 4384U
#   Found valid neighbors: []
#   No valid data found for node 4384U (remains NaN)
#
# Filling node 4386U
#   Found valid neighbors: []
#   No valid data found for node 4386U (remains NaN)
#
# Filling node 4388U
#   Found valid neighbors: ['4388R', '4389R']
#
# Filling node 4410V
#   Found valid neighbors: ['4320RG', '4328V', '3586', '3663', '3946', '3946C2']
#
# Filling node 4415RG
#   Found valid neighbors: ['4414V', '4413V', '4412V', '4411V', '4410V', '4320RG', '4328V', '3586', '3663', '3946', '3946C2']
#
# Filling node 4469RG
#   Found valid neighbors: ['4387V', '4388V', '4386V', '4389V', '4390V', '4391V', '4392V']
#
# Filling node 4500RG
#   Found valid neighbors: ['4500LP', '4506V', '4507V', '4508V', '4520V', '4502V', '4268V1', '4521V', '4501V', '4522V', '4500V']
#
# Filling node 4503V
#   Found valid neighbors: ['4520V', '4502V', '4521V', '4501V', '4522V', '4500V']
#
# Filling node 4504V
#   Found valid neighbors: ['4503V', '4520V', '4502V', '4521V', '4501V', '4522V', '4500V']
#
# Filling node 4505V
#   Found valid neighbors: ['4506V', '4504V', '4507V', '4503V', '4508V', '4520V', '4502V', '4268V1', '4521V', '4501V', '4522V', '4500V']
#
# Filling node 4514R
#   Found valid neighbors: ['4513V']
#
# Filling node 5001U
#   Found valid neighbors: []
#   No valid data found for node 5001U (remains NaN)
#
# Filling node 5052F
#   Found valid neighbors: []
#   No valid data found for node 5052F (remains NaN)
#
# Filling node 6003
#   Found valid neighbors: ['6004', '6107', '6010', '4067WS', '6009', '4067RGWS', '4069', '4070']
#
# Filling node 6006
#   Found valid neighbors: ['6010', '4067WS', '6009', '4067RGWS', '4069', '4070']
#
# Filling node 6007
#   Found valid neighbors: ['6010', '4067WS', '6009', '4067RGWS', '4069', '4070']
#
# Filling node 6008
#   Found valid neighbors: ['6007', '6010', '4067WS', '6009', '4067RGWS', '4069', '4070']
#
# Filling node 6062
#   Found valid neighbors: ['4067WS', '4067RGWS', '4069', '4070']
#
# Filling node 6063
#   Found valid neighbors: []
#   No valid data found for node 6063 (remains NaN)
#
# Filling node 6068
#   Found valid neighbors: []
#   No valid data found for node 6068 (remains NaN)
#
# Filling node 6069
#   Found valid neighbors: []
#   No valid data found for node 6069 (remains NaN)
#
# Filling node 6072U2
#   Found valid neighbors: []
#   No valid data found for node 6072U2 (remains NaN)
#
# Filling node 6103
#   Found valid neighbors: ['6009']
#
# Filling node 6104
#   Found valid neighbors: ['6009']
#
# Filling node 6104m
#   Found valid neighbors: ['6104', '6009']
#
# Filling node 6106
#   Found valid neighbors: ['6008', '6007', '6010', '4067WS', '6009', '4067RGWS', '4069', '4070']
#
# Filling node 6113
#   Found valid neighbors: ['6104', '6009']
#
# Filling node 6137
#   Found valid neighbors: []
#   No valid data found for node 6137 (remains NaN)
#
# Filling node 6141
#   Found valid neighbors: []
#   No valid data found for node 6141 (remains NaN)
#
# Filling node 6162
#   Found valid neighbors: []
#   No valid data found for node 6162 (remains NaN)
#
# Filling node 6163
#   Found valid neighbors: []
#   No valid data found for node 6163 (remains NaN)
#
# Filling node 6169
#   Found valid neighbors: []
#   No valid data found for node 6169 (remains NaN)
#
# Filling node 6201U
#   Found valid neighbors: []
#   No valid data found for node 6201U (remains NaN)
#
# Filling node 6205U
#   Found valid neighbors: []
#   No valid data found for node 6205U (remains NaN)
#
# Filling node 6209U
#   Found valid neighbors: ['6209C2']
#
# Filling node 6217U
#   Found valid neighbors: ['6217C2']
#
# Filling node 6222U
#   Found valid neighbors: []
#   No valid data found for node 6222U (remains NaN)
#
# Filling node 6224U
#   Found valid neighbors: ['6224C2']
#
# Filling node 6257U
#   Found valid neighbors: ['6257C2']
#
# Filling node 6260U
#   Found valid neighbors: ['6260C2']
#
# Filling node 6277U
#   Found valid neighbors: []
#   No valid data found for node 6277U (remains NaN)
#
# Filling node 6459U
#   Found valid neighbors: ['6459', '6558', '6458', '6457', '6455']
#
# Filling node 6579A
#   Found valid neighbors: []
#   No valid data found for node 6579A (remains NaN)
#
# Filling node 6601
#   Found valid neighbors: ['4067WS', '4067RGWS', '4069', '4070']
#
# Filling node 6602
#   Found valid neighbors: ['4067WS', '4067RGWS', '4069', '4070']
#
# Filling node 6604
#   Found valid neighbors: ['6009']
#
# Filling node 6707
#   Found valid neighbors: ['6250C2']
#
# Filling node 6802
#   Found valid neighbors: []
#   No valid data found for node 6802 (remains NaN)
#
# Filling node 6803
#   Found valid neighbors: []
#   No valid data found for node 6803 (remains NaN)
#
# Filling node 6804
#   Found valid neighbors: ['6573', '6572', '6472', '6455']
#
# Filling node 6805
#   Found valid neighbors: []
#   No valid data found for node 6805 (remains NaN)
#
# Filling node 6806
#   Found valid neighbors: []
#   No valid data found for node 6806 (remains NaN)
#
# Filling node 6811U1
#   Found valid neighbors: ['R6811']
#
# Filling node 6811U2
#   Found valid neighbors: ['R6811']
#
# Filling node 6813U
#   Found valid neighbors: []
#   No valid data found for node 6813U (remains NaN)
#
# Filling node 841RG
#   Found valid neighbors: ['121606', '121607', '140625', '140626', '140627', '140628', '142015', '142016', '142017']
#
# Filling node Alcoalaan out
#   Found valid neighbors: []
#   No valid data found for node Alcoalaan out (remains NaN)
#
# Filling node BGT_10
#   Found valid neighbors: []
#   No valid data found for node BGT_10 (remains NaN)
#
# Filling node BGT_10_OUT
#   Found valid neighbors: []
#   No valid data found for node BGT_10_OUT (remains NaN)
#
# Filling node BGT_16
#   Found valid neighbors: []
#   No valid data found for node BGT_16 (remains NaN)
#
# Filling node BGT_16_OUT
#   Found valid neighbors: []
#   No valid data found for node BGT_16_OUT (remains NaN)
#
# Filling node D6007
#   Found valid neighbors: ['D6008']
#
# Filling node D6009
#   Found valid neighbors: ['D6010']
#
# Filling node DR1871
#   Found valid neighbors: ['2779', '3003', '3005', '3006', '3007', '3890', '3552', '3554', '3553', '3556', '3555', '3557', '3559A', '3558', '3560', '3561', '3565', '3562', '3566', '3568', '3569', '3570', '3571', '3572', '3573']
#
# Filling node EH03
#   Found valid neighbors: ['150091']
#
# Filling node F170026
#   Found valid neighbors: []
#   No valid data found for node F170026 (remains NaN)
#
# Filling node HB-WG001
#   Found valid neighbors: []
#   No valid data found for node HB-WG001 (remains NaN)
#
# Filling node Krat_Stationstraat_out
#   Found valid neighbors: []
#   No valid data found for node Krat_Stationstraat_out (remains NaN)
#
# Filling node Metal Vallet E1 out
#   Found valid neighbors: []
#   No valid data found for node Metal Vallet E1 out (remains NaN)
#
# Filling node Metal Valley E2 out
#   Found valid neighbors: []
#   No valid data found for node Metal Valley E2 out (remains NaN)
#
# Filling node Metal Valley E3 out
#   Found valid neighbors: []
#   No valid data found for node Metal Valley E3 out (remains NaN)
#
# Filling node Metal_Vally_out
#   Found valid neighbors: []
#   No valid data found for node Metal_Vally_out (remains NaN)
#
# Filling node OH-WG001
#   Found valid neighbors: []
#   No valid data found for node OH-WG001 (remains NaN)
#
# Filling node OH-WG002
#   Found valid neighbors: []
#   No valid data found for node OH-WG002 (remains NaN)
#
# Filling node OH-WG003
#   Found valid neighbors: []
#   No valid data found for node OH-WG003 (remains NaN)
#
# Filling node OH-WG004
#   Found valid neighbors: []
#   No valid data found for node OH-WG004 (remains NaN)
#
# Filling node OH-WG005
#   Found valid neighbors: []
#   No valid data found for node OH-WG005 (remains NaN)
#
# Filling node OH-WG006
#   Found valid neighbors: []
#   No valid data found for node OH-WG006 (remains NaN)
#
# Filling node OH-WG007
#   Found valid neighbors: []
#   No valid data found for node OH-WG007 (remains NaN)
#
# Filling node R4314
#   Found valid neighbors: []
#   No valid data found for node R4314 (remains NaN)
#
# Filling node RG4353
#   Found valid neighbors: ['V4365']
#
# Filling node VLIJ-002_OUT
#   Found valid neighbors: []
#   No valid data found for node VLIJ-002_OUT (remains NaN)
#
# Filling node wadi10_out
#   Found valid neighbors: []
#   No valid data found for node wadi10_out (remains NaN)
#
# Filling node wadi11A_out
#   Found valid neighbors: []
#   No valid data found for node wadi11A_out (remains NaN)
#
# Filling node wadi11C_out
#   Found valid neighbors: []
#   No valid data found for node wadi11C_out (remains NaN)
#
# Filling node wadi13_out
#   Found valid neighbors: []
#   No valid data found for node wadi13_out (remains NaN)
#
# Filling node wadi14A_out
#   Found valid neighbors: []
#   No valid data found for node wadi14A_out (remains NaN)
#
# Filling node wadi14B_out
#   Found valid neighbors: []
#   No valid data found for node wadi14B_out (remains NaN)
#
# Filling node wadi15A_out
#   Found valid neighbors: []
#   No valid data found for node wadi15A_out (remains NaN)
#
# Filling node wadi15B_out
#   Found valid neighbors: []
#   No valid data found for node wadi15B_out (remains NaN)
#
# Filling node wadi16_out
#   Found valid neighbors: []
#   No valid data found for node wadi16_out (remains NaN)
#
# Filling node wadi20_out
#   Found valid neighbors: []
#   No valid data found for node wadi20_out (remains NaN)
#
# Filling node wadi21_out
#   Found valid neighbors: []
#   No valid data found for node wadi21_out (remains NaN)
#
# Filling node wadi23_out
#   Found valid neighbors: []
#   No valid data found for node wadi23_out (remains NaN)
#
# Filling node wadi24_out
#   Found valid neighbors: []
#   No valid data found for node wadi24_out (remains NaN)
#
# Filling node wadi25_out
#   Found valid neighbors: []
#   No valid data found for node wadi25_out (remains NaN)
#
# Filling node Wadi27_OUT
#   Found valid neighbors: []
#   No valid data found for node Wadi27_OUT (remains NaN)
#
# Filling node wadi4_out
#   Found valid neighbors: []
#   No valid data found for node wadi4_out (remains NaN)
#
# Filling node wadi5a_out
#   Found valid neighbors: []
#   No valid data found for node wadi5a_out (remains NaN)
#
# Filling node wadi5b_out
#   Found valid neighbors: []
#   No valid data found for node wadi5b_out (remains NaN)
#
# Filling node wadi6_out
#   Found valid neighbors: []
#   No valid data found for node wadi6_out (remains NaN)
#
# Filling node wadi7_out
#   Found valid neighbors: []
#   No valid data found for node wadi7_out (remains NaN)
#
# Filling node wadi8_out
#   Found valid neighbors: []
#   No valid data found for node wadi8_out (remains NaN)
#
# Filling node wadi9_out
#   Found valid neighbors: []
#   No valid data found for node wadi9_out (remains NaN)
#
# Filling node Wadi_Milieustraat_out
#   Found valid neighbors: []
#   No valid data found for node Wadi_Milieustraat_out (remains NaN)
#
# Updated node depths:
# 1001: [1.12051, 1.18279, 1.74043, 2.90192, 2.97986, 3.03615, 3.07451, 3.09978, 3.11576, 3.12408, 3.12541, 3.1221, 3.11706]
# 1002: [1.04101, 1.09897, 1.75588, 2.89637, 2.96546, 3.01849, 3.05703, 3.08344, 3.10009, 3.10857, 3.1098, 3.10637, 3.10133]
# 1003: [0.91088, 0.95011, 1.66943, 2.88485, 2.94737, 2.98897, 3.02149, 3.04463, 3.05973, 3.06772, 3.0692, 3.0664, 3.06206]
# 1004: [0.84101, 0.87855, 1.59096, 2.83723, 2.90732, 2.94641, 2.97352, 2.99373, 3.00766, 3.01552, 3.01765, 3.01583, 3.0123]
# 1005: [0.75108, 0.8539, 1.51705, 2.69795, 2.81182, 2.86532, 2.89756, 2.91937, 2.934, 2.94265, 2.94563, 2.94439, 2.94037]
# 1006: [1.15067, 1.29807, 1.88773, 2.94709, 3.02389, 3.07151, 3.10318, 3.12315, 3.13405, 3.13714, 3.13282, 3.12372, 3.11271]
# 1007: [0.66141, 0.79828, 1.42808, 2.56866, 2.70525, 2.76834, 2.80922, 2.83707, 2.8559, 2.86754, 2.87282, 2.87305, 2.86926]
# 1008: [0.58676, 0.75922, 1.21562, 2.49067, 2.68187, 2.74488, 2.78211, 2.8032, 2.81194, 2.80907, 2.79276, 2.7597, 2.7034]
# 1009: [0.56118, 0.72232, 1.06463, 2.42859, 2.6696, 2.72574, 2.75619, 2.76894, 2.76643, 2.74699, 2.70079, 2.6109, 2.50432]
# 1010: [0.52226, 0.67789, 0.99701, 2.36359, 2.65563, 2.70533, 2.72897, 2.73331, 2.7197, 2.6852, 2.61132, 2.51688, 2.43151]
# 1011: [0.50697, 0.61612, 0.88748, 2.23151, 2.61622, 2.65327, 2.6624, 2.64845, 2.61571, 2.56564, 2.48239, 2.4109, 2.35116]
# 1012: [0.44627, 0.51204, 0.75793, 2.16379, 2.56597, 2.59528, 2.59924, 2.58198, 2.54846, 2.50047, 2.42286, 2.36459, 2.31659]
005', 'OH-WG006', 'OH-WG007', 'R4314', 'VLIJ-002_OUT', 'wadi10_out', 'wadi11A_out', 'wadi11C_out', 'wadi13_out', 'wadi14A_out', 'wadi14B_out', 'wadi15A_out', 'wadi15B_out', 'wadi16_out', 'wadi20_out', 'wadi21_out', 'wadi23_out', 'wadi24_out', 'wadi25_out', 'Wadi27_OUT', 'wadi4_out', 'wadi5a_out', 'wadi5b_out', 'wadi6_out', 'wadi7_out', 'wadi8_out', 'wadi9_out', 'Wadi_Milieustraat_out']
# Percentage of nodes which were filled: 27.46%
# Percentage of nodes which were not filled: 72.54%

# %%
# drop the nodes with all NaN values (unconnected nodes, unable to fill)
count = 0
for node in list(G.nodes):  # make a static copy of the node list
    if all(np.isnan(d) for d in G.nodes[node]['depth']):
        G.remove_node(node)
        print(f"Node {node} removed due to all NaN values in depth data.")
        count += 1
print(f'Total number of nodes removed: {count}')
# Out:
# Node 1014U removed due to all NaN values in depth data.
# Node 1030U removed due to all NaN values in depth data.
# Node 110076U1 removed due to all NaN values in depth data.
# Node 110126KRAT_out removed due to all NaN values in depth data.
# Node 110413I_out removed due to all NaN values in depth data.
# Node 110414I_out removed due to all NaN values in depth data.
# Node 110426_out removed due to all NaN values in depth data.
# Node 110516H_OUT removed due to all NaN values in depth data.
# Node 110527I_out removed due to all NaN values in depth data.
# Node 110528I_out removed due to all NaN values in depth data.
# Node 1116U removed due to all NaN values in depth data.
# Node 121589-1U2 removed due to all NaN values in depth data.
# Node 130527A_out removed due to all NaN values in depth data.
# Node 140784_INF_OUT removed due to all NaN values in depth data.
# Node 141236U removed due to all NaN values in depth data.
# Node 150055U removed due to all NaN values in depth data.
# Node 150161U removed due to all NaN values in depth data.
# Node 150202PU removed due to all NaN values in depth data.
# Node 150329VRW_U removed due to all NaN values in depth data.
# Node 160009U removed due to all NaN values in depth data.
# Node 160034 removed due to all NaN values in depth data.
# Node 170013 removed due to all NaN values in depth data.
# Node 170015 removed due to all NaN values in depth data.
# Node 170017 removed due to all NaN values in depth data.
# Node 170020U removed due to all NaN values in depth data.
# Node 170021 removed due to all NaN values in depth data.
# Node 170023 removed due to all NaN values in depth data.
# Node 170025E removed due to all NaN values in depth data.
# Node 170026 removed due to all NaN values in depth data.
# Node 170027 removed due to all NaN values in depth data.
# Node 170030 removed due to all NaN values in depth data.
# Node 170063 removed due to all NaN values in depth data.
# Node 170071 removed due to all NaN values in depth data.
# Node 170100U removed due to all NaN values in depth data.
# Node 170106 removed due to all NaN values in depth data.
# Node 170116C2 removed due to all NaN values in depth data.
# Node 170116U removed due to all NaN values in depth data.
# Node 170117 removed due to all NaN values in depth data.
# Node 170119U removed due to all NaN values in depth data.
# Node 170125U removed due to all NaN values in depth data.
# Node 170139U removed due to all NaN values in depth data.
# Node 170139UPUT_out removed due to all NaN values in depth data.
# Node 170143U removed due to all NaN values in depth data.
# Node 170170U removed due to all NaN values in depth data.
# Node 170190ROV_out removed due to all NaN values in depth data.
# Node 171007U removed due to all NaN values in depth data.
# Node 180022I_out removed due to all NaN values in depth data.
# Node 180030U removed due to all NaN values in depth data.
# Node 190026U removed due to all NaN values in depth data.
# Node 2131AQUA_out removed due to all NaN values in depth data.
# Node 2257AQUA_out removed due to all NaN values in depth data.
# Node 2576U removed due to all NaN values in depth data.
# Node 2672U removed due to all NaN values in depth data.
# Node 2718U removed due to all NaN values in depth data.
# Node 3023AQUA_out removed due to all NaN values in depth data.
# Node 3035_AQUA_OUT removed due to all NaN values in depth data.
# Node 3150S_OUT removed due to all NaN values in depth data.
# Node 3258_out removed due to all NaN values in depth data.
# Node 3268S_OUT removed due to all NaN values in depth data.
# Node 332009U removed due to all NaN values in depth data.
# Node 332040U removed due to all NaN values in depth data.
# Node 332053 removed due to all NaN values in depth data.
# Node 332054 removed due to all NaN values in depth data.
# Node 333050U_OUT removed due to all NaN values in depth data.
# Node 333052U1 removed due to all NaN values in depth data.
# Node 333052U2 removed due to all NaN values in depth data.
# Node 333052U3 removed due to all NaN values in depth data.
# Node 333054U1 removed due to all NaN values in depth data.
# Node 333054U2 removed due to all NaN values in depth data.
# Node 333055R removed due to all NaN values in depth data.
# Node 334013C2 removed due to all NaN values in depth data.
# Node 334013U removed due to all NaN values in depth data.
# Node 334026 removed due to all NaN values in depth data.
# Node 334042C2 removed due to all NaN values in depth data.
# Node 334042U removed due to all NaN values in depth data.
# Node 334045U removed due to all NaN values in depth data.
# Node 334089IK_out removed due to all NaN values in depth data.
# Node 334089U removed due to all NaN values in depth data.
# Node 334142R removed due to all NaN values in depth data.
# Node 334149 removed due to all NaN values in depth data.
# Node 334150 removed due to all NaN values in depth data.
# Node 335031U removed due to all NaN values in depth data.
# Node 335031U2 removed due to all NaN values in depth data.
# Node 336001U removed due to all NaN values in depth data.
# Node 336105U removed due to all NaN values in depth data.
# Node 336378U removed due to all NaN values in depth data.
# Node 336440U removed due to all NaN values in depth data.
# Node 3511INF.1 removed due to all NaN values in depth data.
# Node 3511INFIL._out removed due to all NaN values in depth data.
# Node 3834AU removed due to all NaN values in depth data.
# Node 3850U removed due to all NaN values in depth data.
# Node 3948U removed due to all NaN values in depth data.
# Node 3978IK_out removed due to all NaN values in depth data.
# Node 4013AQUA_out removed due to all NaN values in depth data.
# Node 4054IK_out removed due to all NaN values in depth data.
# Node 4067RGWSU removed due to all NaN values in depth data.
# Node 4074U removed due to all NaN values in depth data.
# Node 4120OU removed due to all NaN values in depth data.
# Node 4170 U removed due to all NaN values in depth data.
# Node 4181 U removed due to all NaN values in depth data.
# Node 4222F_out removed due to all NaN values in depth data.
# Node 4235I_out removed due to all NaN values in depth data.
# Node 4236I_out removed due to all NaN values in depth data.
# Node 4237I_out removed due to all NaN values in depth data.
# Node 4238I_out removed due to all NaN values in depth data.
# Node 4239I_out removed due to all NaN values in depth data.
# Node 4310U3 removed due to all NaN values in depth data.
# Node 4310U4 removed due to all NaN values in depth data.
# Node 4336U1 removed due to all NaN values in depth data.
# Node 4346U2 removed due to all NaN values in depth data.
# Node 4384U removed due to all NaN values in depth data.
# Node 4386U removed due to all NaN values in depth data.
# Node 5001U removed due to all NaN values in depth data.
# Node 5052F removed due to all NaN values in depth data.
# Node 6063 removed due to all NaN values in depth data.
# Node 6068 removed due to all NaN values in depth data.
# Node 6069 removed due to all NaN values in depth data.
# Node 6072U2 removed due to all NaN values in depth data.
# Node 6137 removed due to all NaN values in depth data.
# Node 6141 removed due to all NaN values in depth data.
# Node 6162 removed due to all NaN values in depth data.
# Node 6163 removed due to all NaN values in depth data.
# Node 6169 removed due to all NaN values in depth data.
# Node 6201U removed due to all NaN values in depth data.
# Node 6205U removed due to all NaN values in depth data.
# Node 6222U removed due to all NaN values in depth data.
# Node 6277U removed due to all NaN values in depth data.
# Node 6579A removed due to all NaN values in depth data.
# Node 6802 removed due to all NaN values in depth data.
# Node 6803 removed due to all NaN values in depth data.
# Node 6805 removed due to all NaN values in depth data.
# Node 6806 removed due to all NaN values in depth data.
# Node 6813U removed due to all NaN values in depth data.
# Node Alcoalaan out removed due to all NaN values in depth data.
# Node BGT_10 removed due to all NaN values in depth data.
# Node BGT_10_OUT removed due to all NaN values in depth data.
# Node BGT_16 removed due to all NaN values in depth data.
# Node BGT_16_OUT removed due to all NaN values in depth data.
# Node F170026 removed due to all NaN values in depth data.
# Node HB-WG001 removed due to all NaN values in depth data.
# Node Krat_Stationstraat_out removed due to all NaN values in depth data.
# Node Metal Vallet E1 out removed due to all NaN values in depth data.
# Node Metal Valley E2 out removed due to all NaN values in depth data.
# Node Metal Valley E3 out removed due to all NaN values in depth data.
# Node Metal_Vally_out removed due to all NaN values in depth data.
# Node OH-WG001 removed due to all NaN values in depth data.
# Node OH-WG002 removed due to all NaN values in depth data.
# Node OH-WG003 removed due to all NaN values in depth data.
# Node OH-WG004 removed due to all NaN values in depth data.
# Node OH-WG005 removed due to all NaN values in depth data.
# Node OH-WG006 removed due to all NaN values in depth data.
# Node OH-WG007 removed due to all NaN values in depth data.
# Node R4314 removed due to all NaN values in depth data.
# Node VLIJ-002_OUT removed due to all NaN values in depth data.
# Node wadi10_out removed due to all NaN values in depth data.
# Node wadi11A_out removed due to all NaN values in depth data.
# Node wadi11C_out removed due to all NaN values in depth data.
# Node wadi13_out removed due to all NaN values in depth data.
# Node wadi14A_out removed due to all NaN values in depth data.
# Node wadi14B_out removed due to all NaN values in depth data.
# Node wadi15A_out removed due to all NaN values in depth data.
# Node wadi15B_out removed due to all NaN values in depth data.
# Node wadi16_out removed due to all NaN values in depth data.
# Node wadi20_out removed due to all NaN values in depth data.
# Node wadi21_out removed due to all NaN values in depth data.
# Node wadi23_out removed due to all NaN values in depth data.
# Node wadi24_out removed due to all NaN values in depth data.
# Node wadi25_out removed due to all NaN values in depth data.
# Node Wadi27_OUT removed due to all NaN values in depth data.
# Node wadi4_out removed due to all NaN values in depth data.
# Node wadi5a_out removed due to all NaN values in depth data.
# Node wadi5b_out removed due to all NaN values in depth data.
# Node wadi6_out removed due to all NaN values in depth data.
# Node wadi7_out removed due to all NaN values in depth data.
# Node wadi8_out removed due to all NaN values in depth data.
# Node wadi9_out removed due to all NaN values in depth data.
# Node Wadi_Milieustraat_out removed due to all NaN values in depth data.
# Total number of nodes removed: 177

# %%
# count nodes that still contain negative values in 'depth'

for node in G.nodes:
    G.nodes[node]['depth'] = [
        np.nan if d < 0 else d for d in G.nodes[node]['depth']
    ]

count = sum(
    any(np.isnan(d) for d in G.nodes[node]['depth'])
    for node in G.nodes
)
print(f"{count} nodes still contain negative values in depth data (now turned into NaN).")
# Out:
# 798 nodes still contain negative values in depth data (now turned into NaN).

# %%
# Impute NaN values in the graph using KNN
# Convert node depths to a matrix for imputation
node_list = list(G.nodes)
depth_matrix = np.array([G.nodes[node]['depth'] for node in node_list])

# Apply KNN imputer
imputer = KNNImputer(n_neighbors=5, weights='uniform')
imputed_matrix = imputer.fit_transform(depth_matrix)

# Update graph with imputed values
for i, node in enumerate(node_list):
    G.nodes[node]['depth'] = imputed_matrix[i].tolist()

# Check if there are still NaN values
count = sum(
    any(np.isnan(d) for d in G.nodes[node]['depth'])
    for node in G.nodes
)
print(f"{count} nodes still contain negative values in depth data.")
# Out:
# 0 nodes still contain negative values in depth data.

# %%
# # # Let's add the data to the graph
# # for node in depnod_df.columns[1:]:
# #     if node in G.nodes:
# #         G.nodes[node]['depth'] = depnod_df[node].tolist()
# #     else:
# #         print(f"Node {node} not found in the graph.")

# print(G.nodes(data=True))
# print(f'The length of the graph is {len(G.nodes())}')

# # Now let's visualize the graph with depth values
# depth_values = [G.nodes[node].get('depth', [np.nan])[0] for node in G.nodes()]
# depth_values = np.array(depth_values)

# # Normalize depth values for color mapping
# norm = plt.Normalize(depth_values.min(), depth_values.max())
# cmap = plt.cm.viridis

# # Create the figure and axis objects
# fig, ax = plt.subplots(figsize=(10, 10))

# # Draw the graph
# nx.draw(G, pos=pos, node_size=10, node_color=cmap(norm(depth_values)), with_labels=False, ax=ax)

# # Create the colorbar using a ScalarMappable object
# sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
# sm.set_array([])  # Empty array because we're not plotting images

# # Add the colorbar with the correct label
# fig.colorbar(sm, ax=ax, label='Depth')

# plt.show()

# %%
volume_df = pd.read_csv(os.path.join(folder_path, matching_files[7]), skiprows=[1])

# Get rid of time column
volume_df.drop(columns=['Time'], inplace=True)

df_node_volumes = volume_df.drop(columns=['Seconds'], errors='ignore')

# Loop through the nodes in the graph
for node_id in G.nodes:
    # Check if the node ID matches a column in the DataFrame
    if node_id in df_node_volumes.columns:
        # Assign the volume series to the node as an attribute
        G.nodes[node_id]['volume'] = df_node_volumes[node_id].tolist()

# print the first few nodes to check
print(list(G.nodes(data=True))[:5])
# Out:
# [('1001', {'id': '1001', 'x': 461000.65616613504, 'y': 1351690.2559001052, 'depth': [1.12051, 1.18279, 1.74043, 2.90192, 2.97986, 3.03615, 3.07451, 3.09978, 3.11576, 3.12408, 3.12541, 3.1221, 3.11706], 'volume': [0.02051, 0.08279, 0.64043, 11.9017, 27.48964, 38.74707, 46.41965, 51.47404, 54.66883, 56.33362, 56.59962, 55.93713, 54.92867]}), ('1002', {'id': '1002', 'x': 460883.5301818835, 'y': 1351714.5341153282, 'depth': [1.04101, 1.09897, 1.75588, 2.89637, 2.96546, 3.01849, 3.05703, 3.08344, 3.10009, 3.10857, 3.1098, 3.10637, 3.10133], 'volume': [0.02101, 0.07897, 0.73588, 7.67718, 21.89, 37.05985, 50.48392, 60.9431, 68.09482, 71.9045, 72.46945, 70.90369, 68.6431]}), ('1003', {'id': '1003', 'x': 460754.625982409, 'y': 1351744.3241415746, 'depth': [0.91088, 0.95011, 1.66943, 2.88485, 2.94737, 2.98897, 3.02149, 3.04463, 3.05973, 3.06772, 3.0692, 3.0664, 3.06206], 'volume': [0.02088, 0.06011, 0.77943, 2.74993, 7.99661, 15.80265, 23.66128, 30.07642, 34.65122, 37.20094, 37.68631, 36.77635, 35.38588]}), ('1004', {'id': '1004', 'x': 460639.6981608872, 'y': 1351745.505243937, 'depth': [0.84101, 0.87855, 1.59096, 2.83723, 2.90732, 2.94641, 2.97352, 2.99373, 3.00766, 3.01552, 3.01765, 3.01583, 3.0123], 'volume': [0.02101, 0.05855, 0.77096, 2.02316, 3.9713, 7.92034, 12.55768, 16.8496, 20.09449, 22.03534, 22.57437, 22.11184, 21.22951]}), ('1005', {'id': '1005', 'x': 460507.77558870916, 'y': 1351746.6207295011, 'depth': [0.75108, 0.8539, 1.51705, 2.69795, 2.81182, 2.86532, 2.89756, 2.91937, 2.934, 2.94265, 2.94563, 2.94439, 2.94037], 'volume': [0.02108, 0.1239, 0.78705, 1.96795, 2.08182, 2.16749, 2.68728, 3.59694, 4.565, 5.29852, 5.58193, 5.46212, 5.09238]})]

# %%
node_ids = list(G.nodes())
missing_nodes = [n for n in node_ids if 'volume' not in G.nodes[n]]
print(f"Missing nodes: {missing_nodes}")
# Out:
# Missing nodes: ['110076U2', '143254', '143255', '143307U', '170155U2', '334126U', '334148', '336315', '4131', '4134', '4310U1', '4349U-1', '4376u', '4379U', '4388U', '4514R', '6209U', '6217U', '6224U', '6257U', '6260U', '6459U', '6707', '6804', '6811U1', '6811U2', 'D6007', 'D6009']

# %%
# Delete nodes with missing volume data
for node in missing_nodes:
    G.remove_node(node)
    print(f"Node {node} removed due to missing volume data.")
# Out:
# Node 110076U2 removed due to missing volume data.
# Node 143254 removed due to missing volume data.
# Node 143255 removed due to missing volume data.
# Node 143307U removed due to missing volume data.
# Node 170155U2 removed due to missing volume data.
# Node 334126U removed due to missing volume data.
# Node 334148 removed due to missing volume data.
# Node 336315 removed due to missing volume data.
# Node 4131 removed due to missing volume data.
# Node 4134 removed due to missing volume data.
# Node 4310U1 removed due to missing volume data.
# Node 4349U-1 removed due to missing volume data.
# Node 4376u removed due to missing volume data.
# Node 4379U removed due to missing volume data.
# Node 4388U removed due to missing volume data.
# Node 4514R removed due to missing volume data.
# Node 6209U removed due to missing volume data.
# Node 6217U removed due to missing volume data.
# Node 6224U removed due to missing volume data.
# Node 6257U removed due to missing volume data.
# Node 6260U removed due to missing volume data.
# Node 6459U removed due to missing volume data.
# Node 6707 removed due to missing volume data.
# Node 6804 removed due to missing volume data.
# Node 6811U1 removed due to missing volume data.
# Node 6811U2 removed due to missing volume data.
# Node D6007 removed due to missing volume data.
# Node D6009 removed due to missing volume data.

# %%
# import pickle

# with open(multiple_pickle_path, "wb") as f:
#     pickle.dump(G, f)

# %%
# # Visualize the depth of the nodes in the graph.

# # Select the first 100 nodes from the graph (ensure the graph has at least 100 nodes)
# first_100_nodes = list(G.nodes())[:100]

# # Get the positions for only the first 100 nodes
# pos_sample = {node: pos[node] for node in first_100_nodes}

# # Get depth values for the first 100 nodes
# depth_values_sample = [G.nodes[node].get('depth', [np.nan])[6] for node in first_100_nodes]
# depth_values_sample = np.array(depth_values_sample)

# # Normalize the depth values for color mapping
# norm = plt.Normalize(depth_values_sample.min(), depth_values_sample.max())
# cmap = plt.cm.viridis

# # Create the figure and axis
# fig, ax = plt.subplots(figsize=(10, 10))

# # Draw only the first 100 nodes with the depth-based coloring
# nx.draw_networkx_nodes(G, pos=pos_sample, nodelist=first_100_nodes, node_size=50, node_color=cmap(norm(depth_values_sample)), ax=ax)

# # Create the colorbar using a ScalarMappable object
# sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
# sm.set_array([])  # Empty array because we're not plotting images

# # Add the colorbar with the correct label
# fig.colorbar(sm, ax=ax, label='Depth')

# plt.show()

# %%
# Calculate the mean depth per node
depth_means = {node: np.nanmean(G.nodes[node]['depth']) for node in G.nodes()}

# Convert the means into a numpy array for processing
depth_values = np.array(list(depth_means.values()))

# Calculate the overall mean and standard deviation of the depth values
overall_mean = np.nanmean(depth_values)
overall_std = np.nanstd(depth_values)

# Calculate z-scores
depth_z_scores = (depth_values - overall_mean) / overall_std

# Identify outliers based on z-scores greater than 3 or less than -3
outliers = np.where(np.abs(depth_z_scores) > 3)[0]

# Retrieve the nodes corresponding to the outliers
outlier_nodes = [list(depth_means.keys())[i] for i in outliers]

# Print the results
print(f"Outlier nodes: {outlier_nodes}")
print(f"Outlier depth values: {depth_values[outliers]}")
print(f"Amount of outliers: {len(outliers)}")
# Out:
# Outlier nodes: ['3087', '3100', '3101', '3102', '3103', '3104', '3179', '3180', '3181', '3182', '3184', '3185', '3186', '3187', '3188', '3189', '3190', '3191', '3280', '3281', '3282', '3293', '3773']
# Outlier depth values: [5.71946692 5.50469846 5.71244231 5.69155231 5.43588846 5.06078308
#  4.91508692 5.13293154 5.18190692 5.19843923 4.88576    5.23084077
#  5.48365462 5.61741692 5.65568923 5.70609692 5.72028538 5.72910154
#  6.40630923 6.31389154 5.88614769 5.67827538 5.3236    ]
# Amount of outliers: 23

# %%
# print('Length of the graph before removing outliers:', len(G.nodes()))
# # Remove outlier nodes from the graph
# for node in list(G.nodes):
#     if node in outlier_nodes:
#         G.remove_node(node)
#         print(f"Node {node} removed due to being an outlier.")

# print('Length of the graph after removing outliers:', len(G.nodes()))

# %%
# import pickle

# with open("../pickle/depnod_graph_10.pkl", "wb") as f:
#     pickle.dump(G, f)

# %%
import os

folder_path = '../Run_C2100_Reeks_DWA_20250422_000959'

file_count = 0
for entry in os.listdir(folder_path):
    if os.path.isfile(os.path.join(folder_path, entry)):
        file_count += 1

print(f"Number of files: {file_count}")
# Out:
# Number of files: 4016
